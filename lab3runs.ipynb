# %%
from lab3scripts import *

# %%
l1=do_it(LinearNetwork(train_dataset,500))
# Out:
# batch:1428 loss:0.9501 val_loss:0.9571: 100%|██████████| 42870/42870 [15:25<00:00, 46.32it/s]

# %%
l2=do_it(LinearNetwork(train_dataset,1000))
# Out:
# batch:1428 loss:0.9181 val_loss:0.9097: 100%|██████████| 42870/42870 [15:35<00:00, 45.81it/s]

# %%
c1=do_it(ConvNetwork(train_dataset,init="orth"))
# Out:
# batch:1428 loss:0.5740 val_loss:0.5790: 100%|██████████| 42870/42870 [17:05<00:00, 41.81it/s]

# %%
c1x=do_it(ConvNetwork(train_dataset,init="xe"))
# Out:
# batch:1428 loss:1.1154 val_loss:1.0653: 100%|██████████| 42870/42870 [24:10<00:00, 29.55it/s]

# %%
c1u=do_it(ConvNetwork(train_dataset,init="uniform"))
# Out:
# batch:269 loss:2.4335 val_loss:2.7737:   7%|▋         | 3128/42870 [01:11<09:08, 72.47it/s]

# %%
c2=do_it(ConvNetwork2(train_dataset,init="orth"))
# Out:
# batch:1428 loss:0.5278 val_loss:0.5335: 100%|██████████| 42870/42870 [17:31<00:00, 40.76it/s]

# %%
c2x=do_it(ConvNetwork2(train_dataset,init="xe"))
# Out:
# batch:1428 loss:0.2228 val_loss:0.5423: 100%|██████████| 42870/42870 [16:17<00:00, 43.87it/s]

# %%
c2u=do_it(ConvNetwork(train_dataset,init="uniform"))
# Out:
# batch:1399 loss:nan val_loss:nan:  23%|██▎       | 9975/42870 [04:31<14:55, 36.74it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Johnson\GitHub\math474\lab3runs.ipynb Cell 9 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2B71.199.20.85/c%3A/Users/Johnson/GitHub/math474/lab3runs.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> c2u=do_it(ConvNetwork(train_dataset,init="uniform"))
#
# File c:\Users\Johnson\GitHub\math474\lab3scripts.py:164, in do_it(model)
#     161 loop =tqdm(total=len(train_loader)*num_epochs, position = 0)
#     163 for epoch in range(num_epochs):
# --> 164   for  batch, (x,y_truth) in enumerate(train_loader):
#     165     x,y_truth = x.cuda(non_blocking=True), y_truth.cuda(non_blocking=True)
#     167     optimizer.zero_grad()
#
# ...

# %%
c3=do_it(ConvNetwork3(train_dataset,init="orth"))
# Out:
# batch:1428 loss:0.5349 val_loss:0.5333: 100%|██████████| 42870/42870 [17:04<00:00, 41.86it/s]

# %%
c3x=do_it(ConvNetwork3(train_dataset,init="xe"))
# Out:
# batch:1428 loss:0.5418 val_loss:0.5177: 100%|██████████| 42870/42870 [17:04<00:00, 41.84it/s]

# %%
c3u=do_it(ConvNetwork(train_dataset,init="uniform"))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Johnson\GitHub\math474\lab3runs.ipynb Cell 11 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Johnson/GitHub/math474/lab3runs.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> c3u=do_it(ConvNetwork(train_dataset,init="uniform"))
#
# File c:\Users\Johnson\GitHub\math474\lab3scripts.py:76, in ConvNetwork.__init__(self, dataset, init)
#      73 c,h,w = x.size()
#      74 out_dim = 10
# ---> 76 self.net = nn.Sequential( Conv2d(c,9,(3,3), padding=(1,1),init=init),
#      77                          torch.nn.ReLU(),
#      78                          Conv2d(9,out_dim,(28,28), padding=(0,0),init=init) )
#
# File c:\Users\Johnson\GitHub\math474\lab3scripts.py:38, in Conv2d.__init__(self, in_channels, out_channels, kernel_size, stride, padding, dilation, groups, bias, padding_mode, device, dtype, init)
# ...
