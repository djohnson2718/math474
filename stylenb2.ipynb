# %%
from PIL import Image

# %%
sf = Image.open("images/input.jpg")
war = Image.open("images/warsaw.jpg")
hh = Image.open("images/hh.jpg")
ana = Image.open("images/ana.jpg")

# %%
import style_orig_no_warm
import style_simplified

# %%
style_orig_no_warm.StyleTransfer().stylize(sf, [hh])
# Out:
# processing content image 128x72
# processing style image 0 128x72
# processing content image 181x102
# processing style image 0 181x101
# processing content image 256x144
# processing style image 0 256x143
# processing content image 362x204
# processing style image 0 300x168
# processing content image 512x288
# processing style image 0 300x168
# <PIL.Image.Image image mode=RGB size=512x288>

# %%
style_simplified.StyleTransfer().stylize(sf, hh)
# Out:
# processing content image 512x288
# processing style image 512x287
# <PIL.Image.Image image mode=RGB size=512x288>

# %%
style_orig_no_warm.StyleTransfer().stylize(ana, [hh])
# Out:
# processing content image 96x128
# processing style image 0 128x72
# processing content image 136x181
# processing style image 0 181x101
# processing content image 192x256
# processing style image 0 256x143
# processing content image 272x362
# processing style image 0 300x168
# processing content image 384x512
# processing style image 0 300x168
# <PIL.Image.Image image mode=RGB size=384x512>

# %%
style_simplified.StyleTransfer().stylize(ana, hh)
# Out:
# processing content image 384x512
# processing style image 512x287
# <PIL.Image.Image image mode=RGB size=384x512>

# %%
style_simplified.StyleTransfer().stylize(sf, war)
# Out:
# processing content image 512x288
# processing style image 512x300
# <PIL.Image.Image image mode=RGB size=512x288>

# %%
style_simplified.StyleTransfer().stylize(sf, war, style_weight=4)
# Out:
# processing content image 512x288
# processing style image 512x300
# <PIL.Image.Image image mode=RGB size=512x288>
